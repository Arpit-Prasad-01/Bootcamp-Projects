# %%
# Starting from Python
# Basic Introduction

print("Hello India")
print("Arpit")


print("Hello India")
print("Hello Arpit\n")
print("Hello \r Arpit")
print('hello arpi','t')
print('''hello \t aps''')


# Variables are containers for storing data values.
a = 79  # a is an integer
print(1e308) # itne handle kr skta hai integer me

b = 98.22 # b ia an floating point number
print(1.5e308) # itne handle kr skta hai float me
c = "arpi" # c is an string

d = True # d is an boolean number
e = False # e is an boolean number

f = None # f is an none type variable



a = 20
b = 99.98
c = True
d = "virat"
e = None
f = 3+4j # Complex


print(type(a),a)
print(type(b),b)
print(type(c),c)
print(type(d),d)
print(type(e),e)
print(type(f),f)

num=6
isprime=False

print(type(isprime),isprime)


Name = "Arpit"
age = 20
PI = 3.14

name,age,PI = "arp",20,3.14
print(name,age,PI)

print("The Value of PI is:",PI)
print(Name,PI,age)
print(age-2)
print(age+PI)


# variable and function,class is identifiers or name create means identifiers
# Rules of Identifiers-> english alphabets-- A-Z ,a-z,digit-- 0 to 9,underscore
# not starting from digit and no while space is not allowed and no special character are allowed

_age=19 # allowed
# 7age=12 not allowed
a_56 = 78 # allowed
NAME = "ARPIT" # allowed
# p i=3.14 not allowed
# n@me="rishab"  not allowed

# Dynamic typing
l=5
m=5.9

# Static typing
# int a=5

# Keywords are the reserved word in python not working like a variables


age = int(input("Enter the age:"))

if(age<13):
    print("Child")
elif(age>=13 and age<=18):
    print("Teenager")
else:
    print("Adult")



def check_result(marks):
    if marks >= 27:
        # Executes if the condition is True
        return "Pass"
    else:
        # Executes if all preceding conditions are False
        return "Fail"

student1 = check_result(35)
student2 = check_result(20)

print("Result 1:", student1)
print("Result 2:", student2)



 # loops means repitation
# how many times of run toh use krenge for loop (count)

# while loop   -- jb tk condition true na ho jb tk chlta rhega

#infinte loop
# while (True):
    # print("Hello World")

i = 1 # iterator

while (i<=8):
    print("Hello World",i)
    i += 1 # with the help of counter (iteration)---repeating number of times

print("after the loop, count=",i)

# String
name = "Arpit"

nameshort = name[0:4] # start from index 0 all the way till 4 (excluding)
character1 = name[1]
print(nameshort)
print(character1)
# Out:
# Hello India
# Arpit
# Hello India
# Hello Arpit
#
#  Arpit
# hello arpi t
# hello 	 aps
# 1e+308
# 1.5e+308
# <class 'int'> 20
# <class 'float'> 99.98
# <class 'bool'> True
# <class 'str'> virat
# <class 'NoneType'> None
# <class 'complex'> (3+4j)
# <class 'bool'> False
# arp 20 3.14
# The Value of PI is: 3.14
# Arpit 3.14 20
# 18
# 23.14
# Enter the age:18
# Teenager
# Result 1: Pass
# Result 2: Fail
# Hello World 1
# Hello World 2
# Hello World 3
# Hello World 4
# Hello World 5
# Hello World 6
# Hello World 7
# Hello World 8
# after the loop, count= 9
# Arpi
# r
